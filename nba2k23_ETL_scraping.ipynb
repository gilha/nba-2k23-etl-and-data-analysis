# %% [markdown]
# # NBA 2K23 Game - ETL
# * Scraping the raw data from 2kratings.com
# * Extracting and cleaning it
# * `pandas`, `re`, `BeautifulSoup`, `selenium`

# %% [markdown]
# ## Extraction

# %%
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# %%
def scrape_site(url):
    options = Options()
    options.page_load_strategy='none'
    options.add_argument("start-maximized")
    options.add_argument("enable-automation")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    options.add_argument("--disable-browser-side-navigation")
    options.add_argument("--disable-gpu")
    
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    driver.get(url)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    driver.quit()
    return soup

# %%
teams_url = r'https://www.2kratings.com/current-teams/'

soup_teams = scrape_site(teams_url)
teams_raw = soup_teams.body.find_all('tbody')[0].find_all('tr')

teams = []
for team in teams_raw:
    teams.append([team.a['href'], str(team.a.text).strip()])
teams
# Out:
# [['https://www.2kratings.com/teams/atlanta-hawks', 'Atlanta Hawks'],
#  ['https://www.2kratings.com/teams/boston-celtics', 'Boston Celtics'],
#  ['https://www.2kratings.com/teams/brooklyn-nets', 'Brooklyn Nets'],
#  ['https://www.2kratings.com/teams/charlotte-hornets', 'Charlotte Hornets'],
#  ['https://www.2kratings.com/teams/chicago-bulls', 'Chicago Bulls'],
#  ['https://www.2kratings.com/teams/cleveland-cavaliers',
#   'Cleveland Cavaliers'],
#  ['https://www.2kratings.com/teams/dallas-mavericks', 'Dallas Mavericks'],
#  ['https://www.2kratings.com/teams/denver-nuggets', 'Denver Nuggets'],
#  ['https://www.2kratings.com/teams/detroit-pistons', 'Detroit Pistons'],
#  ['https://www.2kratings.com/teams/golden-state-warriors',
#   'Golden State Warriors'],
#  ['https://www.2kratings.com/teams/houston-rockets', 'Houston Rockets'],
#  ['https://www.2kratings.com/teams/indiana-pacers', 'Indiana Pacers'],
#  ['https://www.2kratings.com/teams/los-angeles-clippers',
#   'Los Angeles Clippers'],
#  ['https://www.2kratings.com/teams/los-angeles-lakers', 'Los Angeles Lakers'],
#  ['https://www.2kratings.com/teams/memphis-grizzlies', 'Memphis Grizzlies'],
#  ['https://www.2kratings.com/teams/miami-heat', 'Miami Heat'],
#  ['https://www.2kratings.com/teams/milwaukee-bucks', 'Milwaukee Bucks'],
#  ['https://www.2kratings.com/teams/minnesota-timberwolves',
#   'Minnesota Timberwolves'],
#  ['https://www.2kratings.com/teams/new-orleans-pelicans',
#   'New Orleans Pelicans'],
#  ['https://www.2kratings.com/teams/new-york-knicks', 'New York Knicks'],
#  ['https://www.2kratings.com/teams/oklahoma-city-thunder',
#   'Oklahoma City Thunder'],
#  ['https://www.2kratings.com/teams/orlando-magic', 'Orlando Magic'],
#  ['https://www.2kratings.com/teams/philadelphia-76ers', 'Philadelphia 76ers'],
#  ['https://www.2kratings.com/teams/phoenix-suns', 'Phoenix Suns'],
#  ['https://www.2kratings.com/teams/portland-trail-blazers',
#   'Portland Trail Blazers'],
#  ['https://www.2kratings.com/teams/sacramento-kings', 'Sacramento Kings'],
#  ['https://www.2kratings.com/teams/san-antonio-spurs', 'San Antonio Spurs'],
#  ['https://www.2kratings.com/teams/toronto-raptors', 'Toronto Raptors'],
#  ['https://www.2kratings.com/teams/utah-jazz', 'Utah Jazz'],
#  ['https://www.2kratings.com/teams/washington-wizards', 'Washington Wizards']]

# %%
data = {}
for team in teams:
    team_url = team[0]
    team_name = team[1]
    
    soup_roster = scrape_site(team_url)
    roster_raw = soup_roster.find_all('tbody')[0].find_all('span', class_='entry-font')
    
    roster = []
    for player in roster_raw:
        player_url = player.a['href']
        player_name = player.a.text
        roster.append([r'%s' % str(player_url), str(player_name)])
        
    for player in roster:
        player_team = team_name
        player_name = player[1]
        player_url = player[0]
        
        soup_attributes = scrape_site(player_url)
        
        per_player_dict = {}
        
        per_player_dict["Name"] = player_name
        per_player_dict["Team"] = player_team
        per_player_dict["Raw Data"] = soup_attributes
        
        data[player_url] = per_player_dict
        
print('Done!')
# Out:
# Done!

# %%
raw_data_df = pd.DataFrame.from_dict(data, orient='index').rename_axis('url')
raw_data_df['Raw Data'] = raw_data_df['Raw Data'].apply(lambda x: str(x))
raw_data_df.to_pickle('raw_data.pkl')

# %% [markdown]
# ## Transformation

# %%
raw_data_df = pd.read_pickle('raw_data.pkl')

def str_to_bs4(x):
    html_soup = BeautifulSoup(x, 'html.parser')
    return html_soup

raw_data_df["Raw Data"] = raw_data_df["Raw Data"].apply(lambda x: str_to_bs4(x))

raw_data_df
# Out:
#                                                       Name  \
# url
# https://www.2kratings.com/trae-young            Trae Young
# https://www.2kratings.com/dejounte-murray  Dejounte Murray
# https://www.2kratings.com/clint-capela        Clint Capela
# https://www.2kratings.com/onyeka-okongwu    Onyeka Okongwu
# https://www.2kratings.com/john-collins        John Collins
# ...                                                    ...
# https://www.2kratings.com/anthony-gill        Anthony Gill
# https://www.2kratings.com/xavier-cooks        Xavier Cooks
# https://www.2kratings.com/isaiah-todd-2        Isaiah Todd
# https://www.2kratings.com/quenton-jackson  Quenton Jackson
# https://www.2kratings.com/jay-huff                Jay Huff
#
#                                                          Team  \
# url
# https://www.2kratings.com/trae-young            Atlanta Hawks
# https://www.2kratings.com/dejounte-murray       Atlanta Hawks
# https://www.2kratings.com/clint-capela          Atlanta Hawks
# https://www.2kratings.com/onyeka-okongwu        Atlanta Hawks
# https://www.2kratings.com/john-collins          Atlanta Hawks
# ...                                                       ...
# https://www.2kratings.com/anthony-gill     Washington Wizards
# https://www.2kratings.com/xavier-cooks     Washington Wizards
# https://www.2kratings.com/isaiah-todd-2    Washington Wizards
# https://www.2kratings.com/quenton-jackson  Washington Wizards
# https://www.2kratings.com/jay-huff         Washington Wizards
#
#                                                                                     Raw Data
# url
# https://www.2kratings.com/trae-young       [[[<meta charset="utf-8"/>, <meta content="IE=...
# https://www.2kratings.com/dejounte-murray  [[[<meta charset="utf-8"/>, <meta content="IE=...
# https://www.2kratings.com/clint-capela     [[[<meta charset="utf-8"/>, <meta content="IE=...
# https://www.2kratings.com/onyeka-okongwu   [[[<meta charset="utf-8"/>, <meta content="IE=...
# https://www.2kratings.com/john-collins     [[[<meta charset="utf-8"/>, <meta content="IE=...
# ...                                                                                      ...
# https://www.2kratings.com/anthony-gill     [[[<meta charset="utf-8"/>, <meta content="IE=...
# https://www.2kratings.com/xavier-cooks     [[[<meta charset="utf-8"/>, <meta content="IE=...
# https://www.2kratings.com/isaiah-todd-2    [[[<meta charset="utf-8"/>, <meta content="IE=...
# https://www.2kratings.com/quenton-jackson  [[[<meta charset="utf-8"/>, <meta content="IE=...
# https://www.2kratings.com/jay-huff         [[[<meta charset="utf-8"/>, <meta content="IE=...
#
# [512 rows x 3 columns]

# %%
raw_data_dict = raw_data_df.to_dict(orient='index')

# %%
final_dict = {}
for player_url in raw_data_dict.keys():
    player_name = raw_data_dict[player_url]['Name']
    player_team = raw_data_dict[player_url]['Team']
    scrape_date = pd.to_datetime('today').strftime('%Y-%m-%d')
    
    raw_data = raw_data_dict[player_url]['Raw Data']
    
    per_player_dict = {}
    per_player_dict['Name'] = player_name
    per_player_dict['Team'] = player_team
    per_player_dict['scrape_date'] = scrape_date
    per_player_dict['Overall Rating'] = raw_data.find_all('span', class_='attribute-box-player')[0].text
                
    ######################## Header Subtitle ########################

    player_info = raw_data.find_all('div', class_='header-subtitle')[0].find_all('p', class_='mb-0')
    for info in player_info:
        text = info.text
        if 'Nationality' in text:
            per_player_dict['Nationality'] = text.split(':')[-1].strip()
        if 'Archetype' in text:
            per_player_dict['Archetype'] = text.split(':')[-1].strip()
        if 'Position' in text:
            per_player_dict['Position'] = text.split(':')[-1].strip()
        if 'Height' and 'Weight' in text:
            height, weight = text.split('|')[0].strip().split(':')[-1].strip(), text.split('|')[-1].split(':')[-1].strip()
            per_player_dict['Height'] = height
            per_player_dict['Weight'] = weight
        if 'Jersey' in text:
            per_player_dict['Jersey'] = text.split('#')[-1].strip()
        if 'in the NBA' in text:
            per_player_dict['Years in NBA'] = text.split(':')[-1].strip()
        if 'Prior to' in text:
            per_player_dict['Prior to NBA'] = text.split(':')[-1].strip()



    ############################# About #############################

    player_about = raw_data.find_all('div', class_='card-body py-3 mb-1')[0].text

    def regex_search(text, regex):
        regex_match = re.search(regex, text)
        if regex_match:
            return regex_match.group(0)
        else:
            return pd.NA

    player_undrafted_regex = r"undrafted"
    player_draft_year_regex = r"\b\d{4}\b"
    player_draft_pick_num_regex = r"\b\d+(?=th|st|nd|rd)"
    player_salary_regex = r"(\$[\d,]+)"
    player_age_regex = r"\b\d+(?=-year)"

    player_salary = regex_search(player_about, player_salary_regex)
    player_age = regex_search(player_about, player_age_regex)

    player_undrafted = regex_search(player_about, player_undrafted_regex)

    if pd.notna(player_undrafted):
        player_draft_year = "Undrafted"
        player_draft_pick_num = pd.NA
    else:
        player_draft_year = regex_search(player_about, player_draft_year_regex)
        player_draft_pick_num = regex_search(player_about, player_draft_pick_num_regex)

    per_player_dict['Salary'] = player_salary
    per_player_dict['Age'] = player_age
    per_player_dict['Draft Year'] = player_draft_year
    per_player_dict['Draft Pick Number'] = player_draft_pick_num



    ########################## Attributes ###########################

    attributes_raw = raw_data.find_all('div', class_='row mr-md-n4')[0].find_all('li')
    for attribute in attributes_raw:
        text = attribute.text
        skill_name = text[3:]
        skill_level = text[:2]
        per_player_dict[skill_name] = int(skill_level)



    ############################ Badges ############################

    badge_figure_rawer = raw_data.find_all('div', class_='badge-card')
    badge_figure_raw = badge_figure_rawer[:int(len(badge_figure_rawer)/2)] # remove duplicates

    badges = {}
    for badge_raw in badge_figure_raw:
        name = badge_raw.find_all('h4')[0].text    
        category = badge_raw.find_all('span', class_='badge-pill')[0].text
        description = badge_raw.find_all('p', class_='badge-description')[0].text
        level_raw = badge_raw.find_all('img', class_='card-img')[0]['data-src']
        level = ''
        if '_bronze.' in level_raw:
            level = 'Bronze'
        elif '_silver.' in level_raw:
            level = 'Silver'
        elif '_gold.' in level_raw:
            level = 'Gold'
        elif 'hof.' in level_raw:
            level = 'Hall of Fame'

        badges[name] = {'Badge Category': category, 
                       'Badge Description': description, 
                       'Badge Level': level}

    per_player_dict['Badges'] = badges

    ################################################################

    final_dict[player_url] = per_player_dict

df = pd.DataFrame.from_dict(final_dict, orient='index').rename_axis('url')
df
# Out:
#                                                       Name  \
# url
# https://www.2kratings.com/trae-young            Trae Young
# https://www.2kratings.com/dejounte-murray  Dejounte Murray
# https://www.2kratings.com/clint-capela        Clint Capela
# https://www.2kratings.com/onyeka-okongwu    Onyeka Okongwu
# https://www.2kratings.com/john-collins        John Collins
# ...                                                    ...
# https://www.2kratings.com/anthony-gill        Anthony Gill
# https://www.2kratings.com/xavier-cooks        Xavier Cooks
# https://www.2kratings.com/isaiah-todd-2        Isaiah Todd
# https://www.2kratings.com/quenton-jackson  Quenton Jackson
# https://www.2kratings.com/jay-huff                Jay Huff
#
#                                                          Team scrape_date  \
# url
# https://www.2kratings.com/trae-young            Atlanta Hawks  2023-04-20
# https://www.2kratings.com/dejounte-murray       Atlanta Hawks  2023-04-20
# https://www.2kratings.com/clint-capela          Atlanta Hawks  2023-04-20
# https://www.2kratings.com/onyeka-okongwu        Atlanta Hawks  2023-04-20
# https://www.2kratings.com/john-collins          Atlanta Hawks  2023-04-20
# ...                                                       ...         ...
# https://www.2kratings.com/anthony-gill     Washington Wizards  2023-04-20
# https://www.2kratings.com/xavier-cooks     Washington Wizards  2023-04-20
# https://www.2kratings.com/isaiah-todd-2    Washington Wizards  2023-04-20
# https://www.2kratings.com/quenton-jackson  Washington Wizards  2023-04-20
# https://www.2kratings.com/jay-huff         Washington Wizards  2023-04-20
#
#                                           Overall Rating    Nationality  \
# url
# https://www.2kratings.com/trae-young                  89  United States
# https://www.2kratings.com/dejounte-murray             84  United States
# https://www.2kratings.com/clint-capela                83    Switzerland
# https://www.2kratings.com/onyeka-okongwu              81  United States
# https://www.2kratings.com/john-collins                80  United States
# ...                                                  ...            ...
# https://www.2kratings.com/anthony-gill                72  United States
# https://www.2kratings.com/xavier-cooks                71      Australia
# https://www.2kratings.com/isaiah-todd-2               70  United States
# https://www.2kratings.com/quenton-jackson             68            NaN
# https://www.2kratings.com/jay-huff                    67  United States
#
#                                                              Archetype  \
# url
# https://www.2kratings.com/trae-young                  Offensive Threat
# https://www.2kratings.com/dejounte-murray               2-Way Playshot
# https://www.2kratings.com/clint-capela                     Paint Beast
# https://www.2kratings.com/onyeka-okongwu   2-Way Inside-the-Arc Scorer
# https://www.2kratings.com/john-collins           Inside the Arc Scorer
# ...                                                                ...
# https://www.2kratings.com/anthony-gill               Interior Finisher
# https://www.2kratings.com/xavier-cooks                 Hybrid Defender
# https://www.2kratings.com/isaiah-todd-2                     Lob Threat
# https://www.2kratings.com/quenton-jackson           Perimeter Defender
# https://www.2kratings.com/jay-huff                        Stretch Five
#
#                                           Position         Height  \
# url
# https://www.2kratings.com/trae-young            PG   6'1" (185cm)
# https://www.2kratings.com/dejounte-murray       PG   6'5" (196cm)
# https://www.2kratings.com/clint-capela           C  6'10" (208cm)
# https://www.2kratings.com/onyeka-okongwu    C / PF   6'9" (206cm)
# https://www.2kratings.com/john-collins      PF / C   6'9" (206cm)
# ...                                            ...            ...
# https://www.2kratings.com/anthony-gill          PF   6'8" (203cm)
# https://www.2kratings.com/xavier-cooks     SF / PF   6'8" (203cm)
# https://www.2kratings.com/isaiah-todd-2         PF   6'9" (206cm)
# https://www.2kratings.com/quenton-jackson  SG / PG   6'5" (196cm)
# https://www.2kratings.com/jay-huff               C   7'1" (216cm)
#
#                                                    Weight Jersey  ...  \
# url                                                               ...
# https://www.2kratings.com/trae-young        164lbs (74kg)     11  ...
# https://www.2kratings.com/dejounte-murray   180lbs (81kg)      5  ...
# https://www.2kratings.com/clint-capela     256lbs (115kg)     15  ...
# https://www.2kratings.com/onyeka-okongwu   240lbs (108kg)     17  ...
# https://www.2kratings.com/john-collins     226lbs (102kg)     20  ...
# ...                                                   ...    ...  ...
# https://www.2kratings.com/anthony-gill     230lbs (104kg)     16  ...
# https://www.2kratings.com/xavier-cooks      183lbs (82kg)    NaN  ...
# https://www.2kratings.com/isaiah-todd-2     219lbs (99kg)     14  ...
# https://www.2kratings.com/quenton-jackson   175lbs (79kg)     29  ...
# https://www.2kratings.com/jay-huff         240lbs (108kg)     36  ...
#
#                                           Perimeter Defense Steal Block  \
# url
# https://www.2kratings.com/trae-young                     55    43    32
# https://www.2kratings.com/dejounte-murray                86    59    40
# https://www.2kratings.com/clint-capela                   53    40    78
# https://www.2kratings.com/onyeka-okongwu                 64    42    84
# https://www.2kratings.com/john-collins                   49    37    71
# ...                                                     ...   ...   ...
# https://www.2kratings.com/anthony-gill                   60    32    56
# https://www.2kratings.com/xavier-cooks                   70    52    54
# https://www.2kratings.com/isaiah-todd-2                  52    35    50
# https://www.2kratings.com/quenton-jackson                73    70    40
# https://www.2kratings.com/jay-huff                       32    32    69
#
#                                           Lateral Quickness Help Defense IQ  \
# url
# https://www.2kratings.com/trae-young                     70              58
# https://www.2kratings.com/dejounte-murray                87              85
# https://www.2kratings.com/clint-capela                   60              86
# https://www.2kratings.com/onyeka-okongwu                 69              83
# https://www.2kratings.com/john-collins                   57              74
# ...                                                     ...             ...
# https://www.2kratings.com/anthony-gill                   50              50
# https://www.2kratings.com/xavier-cooks                   71              72
# https://www.2kratings.com/isaiah-todd-2                  65              58
# https://www.2kratings.com/quenton-jackson                78              70
# https://www.2kratings.com/jay-huff                       34              62
#
#                                           Pass Perception  \
# url
# https://www.2kratings.com/trae-young                   70
# https://www.2kratings.com/dejounte-murray              89
# https://www.2kratings.com/clint-capela                 74
# https://www.2kratings.com/onyeka-okongwu               65
# https://www.2kratings.com/john-collins                 38
# ...                                                   ...
# https://www.2kratings.com/anthony-gill                 58
# https://www.2kratings.com/xavier-cooks                 67
# https://www.2kratings.com/isaiah-todd-2                54
# https://www.2kratings.com/quenton-jackson              75
# https://www.2kratings.com/jay-huff                     54
#
#                                            Defensive Consistency  \
# url
# https://www.2kratings.com/trae-young                          30
# https://www.2kratings.com/dejounte-murray                     85
# https://www.2kratings.com/clint-capela                        85
# https://www.2kratings.com/onyeka-okongwu                      65
# https://www.2kratings.com/john-collins                        60
# ...                                                          ...
# https://www.2kratings.com/anthony-gill                        50
# https://www.2kratings.com/xavier-cooks                        65
# https://www.2kratings.com/isaiah-todd-2                       40
# https://www.2kratings.com/quenton-jackson                     65
# https://www.2kratings.com/jay-huff                            50
#
#                                            Offensive Rebound  \
# url
# https://www.2kratings.com/trae-young                      37
# https://www.2kratings.com/dejounte-murray                 36
# https://www.2kratings.com/clint-capela                    93
# https://www.2kratings.com/onyeka-okongwu                  83
# https://www.2kratings.com/john-collins                    43
# ...                                                      ...
# https://www.2kratings.com/anthony-gill                    56
# https://www.2kratings.com/xavier-cooks                    64
# https://www.2kratings.com/isaiah-todd-2                   55
# https://www.2kratings.com/quenton-jackson                 46
# https://www.2kratings.com/jay-huff                        64
#
#                                            Defensive Rebound  \
# url
# https://www.2kratings.com/trae-young                      43
# https://www.2kratings.com/dejounte-murray                 62
# https://www.2kratings.com/clint-capela                    90
# https://www.2kratings.com/onyeka-okongwu                  83
# https://www.2kratings.com/john-collins                    77
# ...                                                      ...
# https://www.2kratings.com/anthony-gill                    47
# https://www.2kratings.com/xavier-cooks                    70
# https://www.2kratings.com/isaiah-todd-2                   59
# https://www.2kratings.com/quenton-jackson                 42
# https://www.2kratings.com/jay-huff                        68
#
#                                                                                       Badges
# url
# https://www.2kratings.com/trae-young       {'Agent 3': {'Badge Category': 'Shooting Badge...
# https://www.2kratings.com/dejounte-murray  {'Ankle Braces': {'Badge Category': 'DEF/REB B...
# https://www.2kratings.com/clint-capela     {'Post Move Lockdown': {'Badge Category': 'DEF...
# https://www.2kratings.com/onyeka-okongwu   {'Aerial Wizard': {'Badge Category': 'Finishin...
# https://www.2kratings.com/john-collins     {'Aerial Wizard': {'Badge Category': 'Finishin...
# ...                                                                                      ...
# https://www.2kratings.com/anthony-gill                                                    {}
# https://www.2kratings.com/xavier-cooks                                                    {}
# https://www.2kratings.com/isaiah-todd-2                                                   {}
# https://www.2kratings.com/quenton-jackson                                                 {}
# https://www.2kratings.com/jay-huff                                                        {}
#
# [512 rows x 53 columns]

# %% [markdown]
# #### TODO:
# * ~~find out column by column where there are null values, and document/fix it~~
# * ~~make position the primary position only~~
# * ~~make nationality the primary nationality only~~
# * ~~split height column to (1) ft and inches column ("height") (2) cm column ("height (cm)")~~
# * ~~make weight kg only~~
# * ~~transform all columns to their proper type~~
# * ~~make a table for badges (with description and type)~~

# %%
df['Age']['https://www.2kratings.com/trae-young'] = 24
df['Age']['https://www.2kratings.com/john-collins'] = 25
df['Age']['https://www.2kratings.com/deandre-hunter'] = 25
df['Age']['https://www.2kratings.com/bruno-fernando'] = 24
df['Age']['https://www.2kratings.com/eugene-omoruyi'] = 26
df['Age']['https://www.2kratings.com/trevor-hudgins'] = 24
df['Age']['https://www.2kratings.com/dewayne-dedmon'] = 33
df['Age']['https://www.2kratings.com/cameron-payne'] = 28
df['Age']['https://www.2kratings.com/cameron-reddish'] = 23
df['Age']['https://www.2kratings.com/kevin-huerter'] = 24
df['Age']['https://www.2kratings.com/damian-jones'] = 27
df['Age']['https://www.2kratings.com/saddiq-bey'] = 24

df['Nationality']['https://www.2kratings.com/jordan-goodwin'] = 'United States'
df['Nationality']['https://www.2kratings.com/quenton-jackson'] = 'United States'

df['Jersey']['https://www.2kratings.com/raiquan-gray'] = 0
df['Jersey']['https://www.2kratings.com/tyty-washington'] = 0
df['Jersey']['https://www.2kratings.com/chance-comanche'] = 35
df['Jersey']['https://www.2kratings.com/xavier-cooks'] = 12

df['Years in NBA']['https://www.2kratings.com/anthony-lamb'] = 2
df['Years in NBA']['https://www.2kratings.com/omer-yurtseven'] = 1
df['Years in NBA']['https://www.2kratings.com/lindell-wigginton'] = 1
df['Years in NBA']['https://www.2kratings.com/kevon-harris'] = 1
df['Years in NBA']['https://www.2kratings.com/jeff-dowtin'] = 1

df['Salary']['https://www.2kratings.com/tyrese-martin'] = '$1,017,781'
df['Salary']['https://www.2kratings.com/donovan-williams'] = '$239,822'
df['Salary']['https://www.2kratings.com/raiquan-gray'] = '$5,849'
df['Salary']['https://www.2kratings.com/dru-smith'] = '$374,357'
df['Salary']['https://www.2kratings.com/dennis-smith-jr'] = '$2,133,278'
df['Salary']['https://www.2kratings.com/kobi-simmons'] = '$32,795'
df['Salary']['https://www.2kratings.com/carlik-jones'] = '$612,162'
df['Salary']['https://www.2kratings.com/sam-merrill'] = '$1,105,522'
df['Salary']['https://www.2kratings.com/mamadi-diakite'] = '$508,891'
df['Salary']['https://www.2kratings.com/eugene-omoruyi'] = '$1,013,119'
df['Salary']['https://www.2kratings.com/jared-rhoden'] = '$307,089'
df['Salary']['https://www.2kratings.com/andre-iguodala'] = '$2,905,851'
df['Salary']['https://www.2kratings.com/willie-cauley-stein'] = '$155,738'
df['Salary']['https://www.2kratings.com/dj-augustin'] = '$633,938'
df['Salary']['https://www.2kratings.com/james-johnson'] = '$3,841,067'
df['Salary']['https://www.2kratings.com/kendall-brown'] = '$508,891'
df['Salary']['https://www.2kratings.com/gabe-york'] = '$32,171'
df['Salary']['https://www.2kratings.com/moussa-diabate'] = '$508,891'
df['Salary']['https://www.2kratings.com/dennis-schroder'] = '$2,641,682'
df['Salary']['https://www.2kratings.com/shaquille-harrison'] = '$134,862'
df['Salary']['https://www.2kratings.com/scotty-pippen-jr'] = '$508,891'
df['Salary']['https://www.2kratings.com/jacob-gilyard'] = '$5,849'
df['Salary']['https://www.2kratings.com/cody-zeller'] = '$743,922'
df['Salary']['https://www.2kratings.com/orlando-robinson'] = '$386,055'
df['Salary']['https://www.2kratings.com/meyers-leonard'] = '$713,558'
df['Salary']['https://www.2kratings.com/ej-liddell'] = '$508,891'
df['Salary']['https://www.2kratings.com/dereon-seabron'] = '$511,816'
df['Salary']['https://www.2kratings.com/daquan-jeffries'] = '$799,403'
df['Salary']['https://www.2kratings.com/olivier-sarr'] = '$90,665'
df['Salary']['https://www.2kratings.com/michael-carter-williams'] = '$652,829'
df['Salary']['https://www.2kratings.com/jay-scrubb'] = '$49,719'
df['Salary']['https://www.2kratings.com/louis-king'] = '$307,089'
df['Salary']['https://www.2kratings.com/jeenathan-williams'] = '$52,644'
df['Salary']['https://www.2kratings.com/justin-minaya'] = '$35,096'
df['Salary']['https://www.2kratings.com/chance-comanche'] = '$26,000'
df['Salary']['https://www.2kratings.com/ibou-badji'] = '$18,226'
df['Salary']['https://www.2kratings.com/john-butler'] = '$503,041'
df['Salary']['https://www.2kratings.com/pj-dozier'] = '$784,654'
df['Salary']['https://www.2kratings.com/sandro-mamukelashvili'] = '$758,395'
df['Salary']['https://www.2kratings.com/christian-koloko'] = '$1,500,000'
df['Salary']['https://www.2kratings.com/kris-dunn'] = '$1,000,001'
df['Salary']['https://www.2kratings.com/luka-samanic'] = '$538,317'
df['Salary']['https://www.2kratings.com/micah-potter'] = '$508,891'
df['Salary']['https://www.2kratings.com/jordan-goodwin'] = '$1,280,206'
df['Salary']['https://www.2kratings.com/xavier-cooks'] = '$140,384'
df['Salary']['https://www.2kratings.com/quenton-jackson'] = '$219,630'

# %%
df['Position'] = df['Position'].apply(lambda x: x.split(' ')[0])

# %%
df['Nationality'] = df['Nationality'].apply(lambda x: x.split('/')[0].strip())

# %%
df['Height (cm)'] = df['Height'].apply(lambda x: x.split('(')[-1][:-3])

# %%
df['Height'] = df['Height'].apply(lambda x: x.split(' (')[0])

# %%
df['Weight'] = df['Weight'].apply(lambda x: x.split(' (')[-1][:-3])

# %%
df['Salary'] = df['Salary'].apply(lambda x: int(x.replace(',', '')[1:]))

# %%
df
# Out:
#                                                       Name  \
# url
# https://www.2kratings.com/trae-young            Trae Young
# https://www.2kratings.com/dejounte-murray  Dejounte Murray
# https://www.2kratings.com/clint-capela        Clint Capela
# https://www.2kratings.com/onyeka-okongwu    Onyeka Okongwu
# https://www.2kratings.com/john-collins        John Collins
# ...                                                    ...
# https://www.2kratings.com/anthony-gill        Anthony Gill
# https://www.2kratings.com/xavier-cooks        Xavier Cooks
# https://www.2kratings.com/isaiah-todd-2        Isaiah Todd
# https://www.2kratings.com/quenton-jackson  Quenton Jackson
# https://www.2kratings.com/jay-huff                Jay Huff
#
#                                                          Team scrape_date  \
# url
# https://www.2kratings.com/trae-young            Atlanta Hawks  2023-04-20
# https://www.2kratings.com/dejounte-murray       Atlanta Hawks  2023-04-20
# https://www.2kratings.com/clint-capela          Atlanta Hawks  2023-04-20
# https://www.2kratings.com/onyeka-okongwu        Atlanta Hawks  2023-04-20
# https://www.2kratings.com/john-collins          Atlanta Hawks  2023-04-20
# ...                                                       ...         ...
# https://www.2kratings.com/anthony-gill     Washington Wizards  2023-04-20
# https://www.2kratings.com/xavier-cooks     Washington Wizards  2023-04-20
# https://www.2kratings.com/isaiah-todd-2    Washington Wizards  2023-04-20
# https://www.2kratings.com/quenton-jackson  Washington Wizards  2023-04-20
# https://www.2kratings.com/jay-huff         Washington Wizards  2023-04-20
#
#                                           Overall Rating    Nationality  \
# url
# https://www.2kratings.com/trae-young                  89  United States
# https://www.2kratings.com/dejounte-murray             84  United States
# https://www.2kratings.com/clint-capela                83    Switzerland
# https://www.2kratings.com/onyeka-okongwu              81  United States
# https://www.2kratings.com/john-collins                80  United States
# ...                                                  ...            ...
# https://www.2kratings.com/anthony-gill                72  United States
# https://www.2kratings.com/xavier-cooks                71      Australia
# https://www.2kratings.com/isaiah-todd-2               70  United States
# https://www.2kratings.com/quenton-jackson             68  United States
# https://www.2kratings.com/jay-huff                    67  United States
#
#                                                              Archetype  \
# url
# https://www.2kratings.com/trae-young                  Offensive Threat
# https://www.2kratings.com/dejounte-murray               2-Way Playshot
# https://www.2kratings.com/clint-capela                     Paint Beast
# https://www.2kratings.com/onyeka-okongwu   2-Way Inside-the-Arc Scorer
# https://www.2kratings.com/john-collins           Inside the Arc Scorer
# ...                                                                ...
# https://www.2kratings.com/anthony-gill               Interior Finisher
# https://www.2kratings.com/xavier-cooks                 Hybrid Defender
# https://www.2kratings.com/isaiah-todd-2                     Lob Threat
# https://www.2kratings.com/quenton-jackson           Perimeter Defender
# https://www.2kratings.com/jay-huff                        Stretch Five
#
#                                           Position Height Weight Jersey  ...  \
# url                                                                      ...
# https://www.2kratings.com/trae-young            PG   6'1"     74     11  ...
# https://www.2kratings.com/dejounte-murray       PG   6'5"     81      5  ...
# https://www.2kratings.com/clint-capela           C  6'10"    115     15  ...
# https://www.2kratings.com/onyeka-okongwu         C   6'9"    108     17  ...
# https://www.2kratings.com/john-collins          PF   6'9"    102     20  ...
# ...                                            ...    ...    ...    ...  ...
# https://www.2kratings.com/anthony-gill          PF   6'8"    104     16  ...
# https://www.2kratings.com/xavier-cooks          SF   6'8"     82     12  ...
# https://www.2kratings.com/isaiah-todd-2         PF   6'9"     99     14  ...
# https://www.2kratings.com/quenton-jackson       SG   6'5"     79     29  ...
# https://www.2kratings.com/jay-huff               C   7'1"    108     36  ...
#
#                                           Steal Block  Lateral Quickness  \
# url
# https://www.2kratings.com/trae-young         43    32                 70
# https://www.2kratings.com/dejounte-murray    59    40                 87
# https://www.2kratings.com/clint-capela       40    78                 60
# https://www.2kratings.com/onyeka-okongwu     42    84                 69
# https://www.2kratings.com/john-collins       37    71                 57
# ...                                         ...   ...                ...
# https://www.2kratings.com/anthony-gill       32    56                 50
# https://www.2kratings.com/xavier-cooks       52    54                 71
# https://www.2kratings.com/isaiah-todd-2      35    50                 65
# https://www.2kratings.com/quenton-jackson    70    40                 78
# https://www.2kratings.com/jay-huff           32    69                 34
#
#                                           Help Defense IQ Pass Perception  \
# url
# https://www.2kratings.com/trae-young                   58              70
# https://www.2kratings.com/dejounte-murray              85              89
# https://www.2kratings.com/clint-capela                 86              74
# https://www.2kratings.com/onyeka-okongwu               83              65
# https://www.2kratings.com/john-collins                 74              38
# ...                                                   ...             ...
# https://www.2kratings.com/anthony-gill                 50              58
# https://www.2kratings.com/xavier-cooks                 72              67
# https://www.2kratings.com/isaiah-todd-2                58              54
# https://www.2kratings.com/quenton-jackson              70              75
# https://www.2kratings.com/jay-huff                     62              54
#
#                                           Defensive Consistency  \
# url
# https://www.2kratings.com/trae-young                         30
# https://www.2kratings.com/dejounte-murray                    85
# https://www.2kratings.com/clint-capela                       85
# https://www.2kratings.com/onyeka-okongwu                     65
# https://www.2kratings.com/john-collins                       60
# ...                                                         ...
# https://www.2kratings.com/anthony-gill                       50
# https://www.2kratings.com/xavier-cooks                       65
# https://www.2kratings.com/isaiah-todd-2                      40
# https://www.2kratings.com/quenton-jackson                    65
# https://www.2kratings.com/jay-huff                           50
#
#                                            Offensive Rebound  \
# url
# https://www.2kratings.com/trae-young                      37
# https://www.2kratings.com/dejounte-murray                 36
# https://www.2kratings.com/clint-capela                    93
# https://www.2kratings.com/onyeka-okongwu                  83
# https://www.2kratings.com/john-collins                    43
# ...                                                      ...
# https://www.2kratings.com/anthony-gill                    56
# https://www.2kratings.com/xavier-cooks                    64
# https://www.2kratings.com/isaiah-todd-2                   55
# https://www.2kratings.com/quenton-jackson                 46
# https://www.2kratings.com/jay-huff                        64
#
#                                            Defensive Rebound  \
# url
# https://www.2kratings.com/trae-young                      43
# https://www.2kratings.com/dejounte-murray                 62
# https://www.2kratings.com/clint-capela                    90
# https://www.2kratings.com/onyeka-okongwu                  83
# https://www.2kratings.com/john-collins                    77
# ...                                                      ...
# https://www.2kratings.com/anthony-gill                    47
# https://www.2kratings.com/xavier-cooks                    70
# https://www.2kratings.com/isaiah-todd-2                   59
# https://www.2kratings.com/quenton-jackson                 42
# https://www.2kratings.com/jay-huff                        68
#
#                                                                                       Badges  \
# url
# https://www.2kratings.com/trae-young       {'Agent 3': {'Badge Category': 'Shooting Badge...
# https://www.2kratings.com/dejounte-murray  {'Ankle Braces': {'Badge Category': 'DEF/REB B...
# https://www.2kratings.com/clint-capela     {'Post Move Lockdown': {'Badge Category': 'DEF...
# https://www.2kratings.com/onyeka-okongwu   {'Aerial Wizard': {'Badge Category': 'Finishin...
# https://www.2kratings.com/john-collins     {'Aerial Wizard': {'Badge Category': 'Finishin...
# ...                                                                                      ...
# https://www.2kratings.com/anthony-gill                                                    {}
# https://www.2kratings.com/xavier-cooks                                                    {}
# https://www.2kratings.com/isaiah-todd-2                                                   {}
# https://www.2kratings.com/quenton-jackson                                                 {}
# https://www.2kratings.com/jay-huff                                                        {}
#
#                                            Height (cm)
# url
# https://www.2kratings.com/trae-young               185
# https://www.2kratings.com/dejounte-murray          196
# https://www.2kratings.com/clint-capela             208
# https://www.2kratings.com/onyeka-okongwu           206
# https://www.2kratings.com/john-collins             206
# ...                                                ...
# https://www.2kratings.com/anthony-gill             203
# https://www.2kratings.com/xavier-cooks             203
# https://www.2kratings.com/isaiah-todd-2            206
# https://www.2kratings.com/quenton-jackson          196
# https://www.2kratings.com/jay-huff                 216
#
# [512 rows x 54 columns]

# %%
df['Overall Rating'] = df['Overall Rating'].apply(lambda x: int(x))

# %%
df['Weight'] = df['Weight'].apply(lambda x: int(x))

# %%
df['Age'] = df['Age'].apply(lambda x: int(x))

# %%
df['Years in NBA'] = df['Years in NBA'].apply(lambda x: int(x))

# %%
mask = df['Draft Pick Number'].notna()
df['Draft Pick Number'][mask] = df['Draft Pick Number'][mask].apply(lambda x: int(x))

# %%
df.dtypes
# Out:
# Name                     object
# Team                     object
# scrape_date              object
# Overall Rating            int64
# Nationality              object
# Archetype                object
# Position                 object
# Height                   object
# Weight                    int64
# Jersey                   object
# Years in NBA              int64
# Prior to NBA             object
# Salary                    int64
# Age                       int64
# Draft Year               object
# Draft Pick Number        object
# Close Shot                int64
# Mid-Range Shot            int64
# Three-Point Shot          int64
# Free Throw                int64
# Shot IQ                   int64
# Offensive Consistency     int64
# Speed                     int64
# Acceleration              int64
# Strength                  int64
# Vertical                  int64
# Stamina                   int64
# Hustle                    int64
# Overall Durability        int64
# Layup                     int64
# Standing Dunk             int64
# Driving Dunk              int64
# Post Hook                 int64
# Post Fade                 int64
# Post Control              int64
# Draw Foul                 int64
# Hands                     int64
# Pass Accuracy             int64
# Ball Handle               int64
# Speed with Ball           int64
# Pass IQ                   int64
# Pass Vision               int64
# Interior Defense          int64
# Perimeter Defense         int64
# Steal                     int64
# Block                     int64
# Lateral Quickness         int64
# Help Defense IQ           int64
# Pass Perception           int64
# Defensive Consistency     int64
# Offensive Rebound         int64
# Defensive Rebound         int64
# Badges                   object
# Height (cm)              object
# dtype: object

# %%
badges_parsed = [dict(zip(d.keys(), [[v['Badge Description'], v['Badge Category']] for v in d.values()])) for d in df['Badges']]

# %%
badges = {}
for player_badges in badges_parsed:
    for badge in player_badges:
        badges[badge] = {'Description': player_badges[badge][0], 'Category': player_badges[badge][1]}

# %%
badges_df = pd.DataFrame.from_dict(badges, orient='index').rename_axis('Name').sort_values(by=['Category', 'Name'])

# %%
badges_df
# Out:
#                                                          Description  \
# Name
# Anchor             A crucial badge for last line of defense bigs,...
# Ankle Braces             Reduces the chances of getting crossed over
# Boxout Beast       Helps rebounders win boxout battles on both of...
# Brick Wall         Increases effectiveness of screens and drains ...
# Challenger         Improves the effectiveness of perimeter shot c...
# ...                                                              ...
# Limitless Range    Boosts the range that one can effectively shoo...
# Middy Magician     Improved ability to knock down mid-range jumpe...
# Slippery Off Ball  Strengthens the player's ability to get the op...
# Space Creator      Ability to hit stepback jumpers and hop shots,...
# Volume Shooter     Boosts shot percentages as shot attempts accru...
#
#                          Category
# Name
# Anchor              DEF/REB Badge
# Ankle Braces        DEF/REB Badge
# Boxout Beast        DEF/REB Badge
# Brick Wall          DEF/REB Badge
# Challenger          DEF/REB Badge
# ...                           ...
# Limitless Range    Shooting Badge
# Middy Magician     Shooting Badge
# Slippery Off Ball  Shooting Badge
# Space Creator      Shooting Badge
# Volume Shooter     Shooting Badge
#
# [64 rows x 2 columns]

# %%
df.to_pickle('nba2k23_data.pkl')
badges_df.to_pickle('nba2k23_badges.pkl')

# %%
df.to_csv('nba2k23_data.csv')
badges_df.to_csv('nba2k23_badges.csv')
